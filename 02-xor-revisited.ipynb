# %% [markdown]
# <a href="https://colab.research.google.com/github/changsin/DeepLearning-101/blob/master/02-xor-revisited.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# [How to solve XOR problem in Keras](https://medium.com/analytics-vidhya/understanding-basics-of-deep-learning-by-solving-xor-problem-cb3ff6a18a06)

# %%
import numpy as np
from keras.layers import Dense
from keras.models import Sequential

# %%
model = Sequential()
model.add(Dense(units=2,activation='relu', input_dim=2))
model.add(Dense(units=1,activation='sigmoid'))
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])
print(model.summary())
print(model.get_weights())
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense (Dense)                (None, 2)                 6
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 3
# ...
# Total params: 9
# Trainable params: 9
# Non-trainable params: 0
# _________________________________________________________________
# None
# [array([[ 0.5100199 ,  0.46125913],
#        [-1.0030258 , -0.0988698 ]], dtype=float32), array([0., 0.], dtype=float32), array([[-0.44403052],
#        [-0.7815317 ]], dtype=float32), array([0.], dtype=float32)]

# %%
x = np.array([[0.,0.],[0.,1.],[1.,0.],[1.,1.]])
y = np.array([0.,1.,1.,0.])

# %%
model.fit(x,y,epochs=500,batch_size=4)
print(model.get_weights())
print(model.predict(x,batch_size=4))
# Out:
# Epoch 1/500
# 1/1 [==============================] - 0s 1ms/step - loss: 0.5336 - accuracy: 0.7500
# Epoch 2/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.5335 - accuracy: 0.7500
# Epoch 3/500
# 1/1 [==============================] - 0s 1ms/step - loss: 0.5334 - accuracy: 0.7500
# Epoch 4/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.5333 - accuracy: 0.7500
# Epoch 5/500
# 1/1 [==============================] - 0s 830us/step - loss: 0.5333 - accuracy: 0.7500
# Epoch 6/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.5332 - accuracy: 0.7500
# Epoch 7/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.5332 - accuracy: 0.7500
# Epoch 8/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.5331 - accuracy: 0.7500
# Epoch 9/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.5331 - accuracy: 0.7500
# Epoch 10/500
# ...
